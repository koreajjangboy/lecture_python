# %%
# from shop.price import calculate_total, apply_discount
import shop.price

subtotal = calculate_total(12000, 3)
final_price = apply_discount(subtotal,0.2)

print(subtotal)
print(final_price)
# Out:
# 36000
# 28800.0
